# %% [markdown]
# # Entire workflow is built on Gemini for purpose of testing LangGraph
#
# Remember to key in API_KEY in config.py before running the following cells

# %%
import main

# %%
from IPython.display import Image, display
# View
display(Image(main.graph.get_graph().draw_mermaid_png()))

# %%
'''
result = main.graph.invoke({"graph_state": "Tell me more about Singapore's Green Plan"})
print(result["graph_state"])
'''
# Out:
# '\nresult = main.graph.invoke({"graph_state": "Tell me more about Singapore\'s Green Plan"})\nprint(result["graph_state"])\n'

# %%
'''
print(result["voice_script"])
'''
# Out:
# '\nprint(result["voice_script"])\n'

# %%
main.main()
# Out:
# Speech Generator ready. Type 'quit' to exit.
# You:  Draft a 10 minute speech on Singapore's Green Plan, to rally Singaporeans to contribute.
# 2026-03-02 20:17:40,712 | INFO | === Planner_Agent START ===
# 2026-03-02 20:17:40,713 | INFO | Input context:
# Draft a 10 minute speech on Singapore's Green Plan, to rally Singaporeans to contribute.
# 2026-03-02 20:17:40,714 | INFO | AFC is enabled with max remote calls: 10.
# Generating your speech...
# 2026-03-02 20:17:45,228 | INFO | HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent "HTTP/1.1 200 OK"
# 2026-03-02 20:17:45,231 | INFO | Plan generated:
# ```json
# {
#   "blueprint_version": "1.0",
#   "request_summary": {
#     "topic": "Rallying Singaporeans to contribute to Singapore's Green Plan",
#     "audience": "General Singaporean public",
#     "occasion": "Public engagement event or national campaign",
#     "time_limit_minutes": 10
#   },
#   "targets": {
# ...
