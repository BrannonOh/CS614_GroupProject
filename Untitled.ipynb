# %%
import main, prompt
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import main, prompt
#
# File /app/main.py:1
# ----> 1 from graph.graph import build_graph
#       3 # Checks if user wants to quit programme
#       4 def prompt(field):
#
# File /app/graph/graph.py:3
#       1 from langgraph.graph import StateGraph, START, END
#       2 from graph.state import SpeechScriptState, route_user, route_ted, route_content, route_style
# ----> 3 from agents.query_agent import Query_Agent
#       4 from agents.planner_agent import Planner_Agent
#       5 from agents.ted_agent import TED_Agent
#
# File /app/agents/query_agent.py:40
#      32 load_dotenv(dotenv_path =".env")
#      33 # os.environ.get("TAVILY_API_KEY")
#      34 # os.environ.get("OPENAI_API_KEY")
#      35
#      36 # %%
#      37 # if not os.environ.get("OPENAI_API_KEY"):
# ...

# %%
main.main
